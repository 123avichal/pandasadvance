# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd

# %%
data=pd.DataFrame({'key1':[1,3,4,5],
                   'key2':[3,4,6,7],
                   'key3':[5,6,3,5]
})


data2=pd.DataFrame({'key1':[1,32,4,52],
                   'key22':[3,44,64,7],
                   'key33':[5,6,3,52]
})

# %%
pd.date_range(start='16-may-1998',end='18-may-1998')
# Out:
# DatetimeIndex(['1998-05-16', '1998-05-17', '1998-05-18'], dtype='datetime64[ns]', freq='D')

# %%
pd.concat([data,data2])
# Out:
#    key1  key2  key3  key22  key33
# 0     1   3.0   5.0    NaN    NaN
# 1     3   4.0   6.0    NaN    NaN
# 2     4   6.0   3.0    NaN    NaN
# 3     5   7.0   5.0    NaN    NaN
# 0     1   NaN   NaN    3.0    5.0
# 1    32   NaN   NaN   44.0    6.0
# 2     4   NaN   NaN   64.0    3.0
# 3    52   NaN   NaN    7.0   52.0

# %%
pd.merge(data,data2)
# Out:
#    key1  key2  key3  key22  key33
# 0     1     3     5      3      5
# 1     4     6     3     64      3

# %%
pd.read_csv('services.csv')
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
df=pd.DataFrame({'A': ['Avichal','harshit','meet','pancham'],
              'B':[ 378,566,789,433],
              'C':['2017-2021','2017-2021','2017-2021','2017-2021']
},index=[1,2,3,4])

# %%
df
# Out:
#          A    B          C
# 1  Avichal  378  2017-2021
# 2  harshit  566  2017-2021
# 3     meet  789  2017-2021
# 4  pancham  433  2017-2021

# %%
l=[1,2,3,4]
df.reindex(l)
# Out:
#          A    B          C
# 1  Avichal  378  2017-2021
# 2  harshit  566  2017-2021
# 3     meet  789  2017-2021
# 4  pancham  433  2017-2021

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df=pd.DataFrame({'text': ['i enrolled in data science masters classes','hello world']
})

# %%
df['word_count']=df['text'].apply(lambda x : len(x.split()))

# %%
df
# Out:
#                                          text  word_count
# 0  i enrolled in data science masters classes           7
# 1                                 hello world           2

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size() -The size property is used to get an int representing the number of elements in this object and Return the number of rows if Series. Otherwise, return the number of rows times the number of columns if DataFrame.
#
#
#
#
# DataFrame.shape()-The shape property is used to get a tuple representing the dimensionality of the Pandas DataFrame.

# %%
df
# Out:
#                                          text  word_count
# 0  i enrolled in data science masters classes           7
# 1                                 hello world           2

# %%
df.size
# Out:
# 4

# %%
df.shape
# Out:
# (2, 2)

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# pd.read_excel()##function is used to rad the excel file by implement the url of excel file in pandas read function

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df=pd.DataFrame({'Values':[1,2,3,4,5,6]
})

# %%
df.mean()
# Out:
# Values    3.5
# dtype: float64

# %%
df.median()
# Out:
# Values    3.5
# dtype: float64

# %%
df.std()
# Out:
# Values    1.870829
# dtype: float64

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
date=pd.date_range(start='1-may-2023',end= '7-may-2023')

# %%
df=pd.DataFrame({'date':date})

# %%
date
# Out:
# DatetimeIndex(['2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df['weekday']=l

# %%
l =['sunday','monday','tuesday','wedbesday','thursday','friday','saturday']

# %%
df
# Out:
#         date    weekday
# 0 2023-05-01     sunday
# 1 2023-05-02     monday
# 2 2023-05-03    tuesday
# 3 2023-05-04  wedbesday
# 4 2023-05-05   thursday
# 5 2023-05-06     friday
# 6 2023-05-07   saturday

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

# %%
df = pd.DataFrame({'Values':[1,2,3,4,5]
},index=['a','b','c','d','e'])

# %%
df1=df[0:3].apply(sum)
df
# Out:
#    Values
# a       1
# b       2
# c       3
# d       4
# e       5

# %%
df1
# Out:
# Values    6
# dtype: int64

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
time_stamp=pd.date_range(start='1-01-2023',end='31-01-2023')
# Out:
# /tmp/ipykernel_84/403725675.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   time_stamp=pd.date_range(start='1-01-2023',end='31-01-2023')

# %%
df= pd.DataFrame({'date':time_stamp
})

# %%
df[0:31]
# Out:
#          date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05
# 5  2023-01-06
# 6  2023-01-07
# 7  2023-01-08
# 8  2023-01-09
# 9  2023-01-10
# 10 2023-01-11
# 11 2023-01-12
# 12 2023-01-13
# 13 2023-01-14
# 14 2023-01-15
# 15 2023-01-16
# 16 2023-01-17
# 17 2023-01-18
# 18 2023-01-19
# 19 2023-01-20
# 20 2023-01-21
# 21 2023-01-22
# 22 2023-01-23
# 23 2023-01-24
# 24 2023-01-25
# 25 2023-01-26
# 26 2023-01-27
# 27 2023-01-28
# 28 2023-01-29
# 29 2023-01-30
# 30 2023-01-31

# %% [markdown]
# Q13.Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %% [markdown]
#  the basic function of pandas to be used to perform the specific task are given below
# 1 read()
# 2 head()
# 3 describe()
# 4 Dataframe()
# 5 Series()
# 6 tail()
# 7 column
# 8 Catagorical()
# 9 ddtypes

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
df= pd.DataFrame({'Sales':[43,54,65,76,54,45,78],
                  'date':['12-04-2023','12-04-2023','13-04-2023','14-04-2023','15-04-2023','16-04-2023','17-04-2023']
})

# %%
df
# Out:
#    Sales        date
# 0     43  12-04-2023
# 1     54  12-04-2023
# 2     65  13-04-2023
# 3     76  14-04-2023
# 4     54  15-04-2023
# 5     45  16-04-2023
# 6     78  17-04-2023

# %%
df['MovingAverage']=df['Sales']

# %%
a=df['MovingAverage'].rolling(window=7)

# %%
a.mean()
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6    59.285714
# Name: MovingAverage, dtype: float64
